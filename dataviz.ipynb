# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
# Out:
# Bad key figure.labelsize in file c:\Users\Rozba\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\mpl-data\stylelib\classic (2).mplstyle, line 310 ('figure.labelsize:   medium    # size of the figure label')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key figure.labelweight in file c:\Users\Rozba\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\mpl-data\stylelib\classic (2).mplstyle, line 311 ('figure.labelweight: normal    # weight of the figure label')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
import seaborn as sns

# %% [markdown]
# # Data visualtion with Python

# %%
# data of height and weight of 10 people in cm and kg
height = [161, 175, 169, 160, 164, 177, 162, 166, 159, 158]
weight = [80, 70, 60, 90, 75, 65, 55, 85, 95, 65]

plt.scatter(x=height, y=weight) # scatter plot

# %%
sns.scatterplot(x=height, y=weight, hue=height, size=weight) # seaborn scatter plot
# Out:
# <AxesSubplot:>

# %%
# load data from seaborn
kashti = sns.load_dataset('titanic')
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ## Seaborn libraries for statistical data visualization
# ### Data Visualization on the Titanic Dataset
# Below are a few examples from the seaborn libraries

# %%
# seaborn Anscombe’s quartet
import seaborn as sns
sns.set_theme(style="ticks")

# dataset kashti

# Show the results of a linear regression within each dataset
sns.lmplot(
    data=kashti, x="age", y="fare", col="sex", hue="pclass",
    col_wrap=2, palette="muted", ci=None,
    height=4, scatter_kws={"s": 50, "alpha": 1}
)

# %%
# seaborn scatterplot
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")

# kashti dataset

# Draw a scatter plot while assigning point colors and sizes to different
# variables in the dataset
f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.despine(f, left=True, bottom=True)
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]
sns.scatterplot(x="age", y="fare",
                hue="pclass", size="sex",
                palette="ch:r=-.2,d=.3_r",
                hue_order=clarity_ranking,
                sizes=(1, 8), linewidth=0,
                data=kashti, ax=ax)
# Out:
# <AxesSubplot:xlabel='age', ylabel='fare'>

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

# dataset kashti

# Plot the responses for different events and regions
sns.lineplot(x="age", y="fare",
             hue="pclass", style="sex",
             data=kashti)
# Out:
# <AxesSubplot:xlabel='age', ylabel='fare'>

# %%
import seaborn as sns

sns.set_theme(style="darkgrid")
#df = sns.load_dataset("titanic")
sns.displot(
    kashti, x="age", col="pclass", row="sex",
    binwidth=3, height=3, facet_kws=dict(margin_titles=True),
)

# %%
# line plots with ,ultiple facets seaborn
import seaborn as sns
sns.set_theme(style="ticks")

# dataset kashti

# Define the palette as a list to specify exact values
palette = sns.color_palette("rocket_r")

# Plot the lines on two facets
sns.relplot(
    data=kashti, x="age", y="fare", hue="pclass",
    kind="line", palette=palette,
    height=5, aspect=.75, facet_kws=dict(sharex=False),
)
# Out:
# C:\Users\Rozba\AppData\Local\Temp\ipykernel_3380\488863891.py:11: UserWarning: The palette list has more values (6) than needed (3), which may not be intended.
#   sns.relplot(

# %%
# Grouped barplots
import seaborn as sns
sns.set_theme(style="whitegrid")

# dataset kashti

# Draw a nested barplot by species and sex
g = sns.catplot(
    data=kashti, kind="bar",
    x="age", y="fare", hue="sex",
    errorbar="sd", palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("", "Body mass (g)")
g.legend.set_title("")

# %%
# Grouped boxplots

sns.set_theme(style="ticks", palette="pastel")

# dataset kashti
# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="fare", y="age",
            hue="pclass", palette=["m", "g"],
            data=kashti)
sns.despine(offset=10, trim=True)

# %% [markdown]
#  This above graph is boxplot (ye box plot lag nahi naha)

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# dataset kashti
# Draw a nested violinplot and split the violins for easier comparison
sns.violinplot(data=kashti, x="sex", y="age", hue="survived",
                inner="quart", linewidth=1,
              )
sns.despine(left=True)

# %%
import numpy as np
import seaborn as sns
sns.set_theme(style="ticks")

rs = np.random.RandomState(11)
x = rs.gamma(2, size=1000)
y = -.5 * x + rs.normal(size=1000)

sns.jointplot(x=x, y=y, kind="hex", color="#4CB391")

# %% [markdown]
# This is not based on kashti dataset. This is based on a dataset of 50 random numbers.
# This is just to show how to make a boxplot in python.

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# Load the brain networks dataset, select subset, and collapse the multi-index
# df = sns.load_dataset("brain_networks", header=[0, 1, 2], index_col=0)
# dataset kashti
used_networks = [1, 5, 6, 7, 8, 12, 13, 17]
used_columns = (kashti.columns
                  
                  .astype(int)
                  .isin(used_networks))
kashti = kashti.loc[:, used_columns]

kashti.columns = kashti.columns.map("-".join)

# Compute a correlation matrix and convert to long-form
corr_mat = kashti.corr().stack().reset_index(name="correlation")

# Draw each cell as a scatter point with varying size and color
g = sns.relplot(
    data=kashti,
    x="age", y="fare", hue="pclass", size="survived",
    palette="vlag", hue_norm=(-1, 1), edgecolor=".7",
    height=10, sizes=(50, 250), size_norm=(-.2, .8),
)

# Tweak the figure to finalize
g.set(xlabel="", ylabel="", aspect="equal")
g.despine(left=True, bottom=True)
g.ax.margins(.02)
for label in g.ax.get_xticklabels():
    label.set_rotation(90)
for artist in g.legend.legendHandles:
    artist.set_edgecolor(".7")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Rozba\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:1117, in Index.astype(self, dtype, copy)
#    1115     else:
#    1116         # GH#13149 specifically use astype_nansafe instead of astype
# -> 1117         new_values = astype_nansafe(values, dtype=dtype, copy=copy)
#    1118 except IntCastingNaNError:
#
# File c:\Users\Rozba\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\dtypes\astype.py:170, in astype_nansafe(arr, dtype, copy, skipna)
#     168 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169     # Explicit copy, or required since NumPy can't view from / to object.
# --> 170     return arr.astype(dtype, copy=True)
#     172 return arr.astype(dtype, copy=copy)
#
# ...

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")

# dataset kashti")

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)

sns.histplot(
    kashti,
    x="age", hue="pclass",
    multiple="stack",
    palette="light:m_r",
    edgecolor=".3",
    linewidth=.5,
    log_scale=True,
)
ax.xaxis.set_major_formatter(mpl.ticker.ScalarFormatter())
ax.set_xticks([500, 1000, 2000, 5000, 10000])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")

# Initialize the figure with a logarithmic x axis
f, ax = plt.subplots(figsize=(7, 6))
ax.set_xscale("log")

# dataset kashti

# Plot the orbital period with horizontal boxes
sns.boxplot(x="fare", y="age", data=kashti,
            whis=[0, 100], width=.3, palette="vlag")

# Add in points to show each observation
sns.stripplot(x="age", y="fare", data=kashti,
              size=4, color=".3", linewidth=0)

# Tweak the visual presentation
ax.xaxis.grid(True)
ax.set(ylabel="")
sns.despine(trim=True, left=True)
# Out:
# c:\Users\Rozba\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:761: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax.set_xlim(-.5, len(self.plot_data) - .5, auto=None)
# c:\Users\Rozba\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1128: RuntimeWarning: divide by zero encountered in log10
#   comp = np.log10(comp)
# c:\Users\Rozba\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:220: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax.set_xlim(-.5, n - .5, auto=None)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")
# dataset kashti
kashti=sns.load_dataset("titanic")
# "Melt" the dataset to "long-form" or "tidy" representation
kashti = pd.melt(kashti, "age", var_name="fare")

# Initialize the figure
f, ax = plt.subplots()
sns.despine(bottom=True, left=True)

# Show each observation with a scatterplot
sns.stripplot(
    data=kashti,
    dodge=True, alpha=.25, zorder=1, legend=False
)

# Show the conditional means, aligning each pointplot in the
# center of the strips by adjusting the width allotted to each
# category (.8 by default) by the number of hue levels
sns.pointplot(
    data=kashti, 
    join=False, dodge=.8 - .8 / 3, palette="dark",
    markers="d", scale=.75, errorbar=None
)
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
sns.set_theme(style="ticks")

# dataset kashti
kashti=sns.load_dataset("titanic")
# Show the joint distribution using kernel density estimation
g = sns.jointplot(
    data=kashti,
    x="age", y="fare", hue="pclass",
    kind="kde",
)

# %%
import seaborn as sns
sns.set_theme(style="ticks")

# dataset kashti
kashti= sns.load_dataset("titanic")
# Show the joint distribution using kernel density estimation
g = sns.jointplot(
    data=kashti,
    x="age", y="fare", hue="sex",
    kind="kde",
)

# %%
kashti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 798336 entries, 0 to 798335
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   pclass  798336 non-null  int64
#  1   sex     798336 non-null  object
#  2   value   797467 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 18.3+ MB

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# dataset kashti
kashti= sns.load_dataset("titanic")
# clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]

sns.boxenplot(x="survived", y="age",
              color="blue", 
              scale="linear", data=kashti)
# Out:
# <AxesSubplot:xlabel='survived', ylabel='age'>

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="dark")

# Simulate data from a bivariate Gaussian
n = 10000
mean = [0, 0]
cov = [(2, .4), (.4, .2)]
rng = np.random.RandomState(0)
x, y = rng.multivariate_normal(mean, cov, n).T

# Draw a combo histogram and scatterplot with density contours
f, ax = plt.subplots(figsize=(6, 6))
sns.scatterplot(x=x, y=y, s=5, color=".15")
sns.histplot(x=x, y=y, bins=50, pthresh=.1, cmap="mako")
sns.kdeplot(x=x, y=y, levels=5, color="w", linewidths=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Above graph is not suitable for kashti dataset.

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

# Load the example Titanic dataset
kashti = sns.load_dataset("titanic")

# Make a custom palette with gendered colors
pal = dict(male="#6495ED", female="#F08080")

# Show the survival probability as a function of age and sex
g = sns.lmplot(x="age", y="survived", col="sex", hue="sex", data=kashti,
               palette=pal, y_jitter=.02, logistic=True, truncate=False)
g.set(xlim=(0, 80), ylim=(-.05, 1.05))

# %%
import seaborn as sns
sns.set_theme(style="white", color_codes=True)
# dataset kashti
kashti= sns.load_dataset("titanic")
# Use JointGrid directly to draw a custom plot
g = sns.JointGrid(data=kashti, x="fare", y="age", space=0, ratio=17)
g.plot_joint(sns.scatterplot, size=kashti["fare"], sizes=(30, 120),
             color="g", alpha=.6, legend=False)
g.plot_marginals(sns.rugplot, height=1, color="g", alpha=.6)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="darkgrid")
kashti= sns.load_dataset("titanic")

# Set up the figure
f, ax = plt.subplots(figsize=(8, 8))
ax.set_aspect("equal")

# Draw a contour plot to represent each bivariate density
sns.kdeplot(
    data=kashti, x="fare", y="age",
    hue="pclass", fill=True,
    thresh=.1,
)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='age'>

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# dataset kashti
kashti= sns.load_dataset("titanic")
# Plot the distribution of clarity ratings, conditional on carat
sns.displot(
    data=kashti,
    x="age", hue="pclass",
    kind="kde", height=6,
    multiple="fill", clip=(0, None),
    palette="ch:rot=-.25,hue=1,light=.75",
)

# %%
import seaborn as sns
sns.set_theme()

# dataset kashti
kashti= sns.load_dataset("titanic")
# Plot the orbital period with horizontal boxes
g = sns.lmplot(
    data=kashti,
    x="age", y="fare", hue="pclass",
    height=5
)


g.set_axis_labels("Male", "Female")

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="white", context="talk")
rs = np.random.RandomState(8)

# Set up the matplotlib figure
f, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(7, 5), sharex=True)

# Generate some sequential data
x = np.array(list("ABCDEFGHIJ"))
y1 = np.arange(1, 11)
sns.barplot(x=x, y=y1, palette="rocket", ax=ax1)
ax1.axhline(0, color="k", clip_on=False)
ax1.set_ylabel("Sequential")

# Center the data to make it diverging
y2 = y1 - 5.5
sns.barplot(x=x, y=y2, palette="vlag", ax=ax2)
ax2.axhline(0, color="k", clip_on=False)
ax2.set_ylabel("Diverging")

# Randomly reorder the data to make it qualitative
y3 = rs.choice(y1, len(y1), replace=False)
sns.barplot(x=x, y=y3, palette="deep", ax=ax3)
ax3.axhline(0, color="k", clip_on=False)
ax3.set_ylabel("Qualitative")

# Finalize the plot
sns.despine(bottom=True)
plt.setp(f.axes, yticks=[])
plt.tight_layout(h_pad=2)

# %% [markdown]
# Above graph is generated on some random data. This is just to show how to make a boxplot in python.

# %%
df=sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 15))

# Load the example kashti dataset
kashti = sns.load_dataset("titanic")

# Plot the total died and survived passengers
sns.set_color_codes("pastel")
sns.barplot(x="survived", y="sex", data=kashti,
            label="survived", color="b")

# Plot the crashes where alcohol was involved
sns.set_color_codes("muted")
sns.barplot(x="pclass", y="survived", data=kashti,
            label="kashti", color="g")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0, 24), ylabel="",
      xlabel="classes")
sns.despine(left=True, bottom=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 15))

# Load the example car crash dataset
crashes = sns.load_dataset("car_crashes").sort_values("total", ascending=False)

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="total", y="abbrev", data=crashes,
            label="Total", color="b")

# Plot the crashes where alcohol was involved
sns.set_color_codes("muted")
sns.barplot(x="alcohol", y="abbrev", data=crashes,
            label="Alcohol-involved", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0, 24), ylabel="",
       xlabel="Automobile collisions per billion miles")
sns.despine(left=True, bottom=True)

# %%
# make horizental bar plot on titanic dataset

# %%
pip install pyforest
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Running setup.py install for pyforest: started
#   Running setup.py install for pyforest: finished with status 'done'
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -illow (c:\users\rozba\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\rozba\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\rozba\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\rozba\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\rozba\appdata\local\programs\python\python310\lib\site-packages)
# ...

# %%
from pyforest import *
lazy_imports()
# Out:
# ['import lightgbm as lgb',
#  'from sklearn.linear_model import Ridge',
#  'import matplotlib as mpl',
#  'from sklearn.preprocessing import RobustScaler',
#  'import os',
#  'from sklearn.preprocessing import LabelEncoder',
#  'from sklearn.model_selection import train_test_split',
#  'from sklearn.feature_extraction.text import TfidfVectorizer',
#  'from sklearn.linear_model import ElasticNet',
#  'from sklearn.feature_extraction.text import CountVectorizer',
#  'from sklearn.linear_model import LinearRegression',
#  'from scipy import signal as sg',
#  'import numpy as np',
#  'from pathlib import Path',
#  'from openpyxl import load_workbook',
#  'import tqdm',
#  'from scipy import stats',
#  'from PIL import Image',
#  'import skimage',
#  'import textblob',
#  'from sklearn import svm',
#  'import bokeh',
#  'import tensorflow as tf',
#  'import altair as alt',
#  'from sklearn.model_selection import StratifiedKFold',
#  'import plotly as py',
#  'import sys',
# ...
