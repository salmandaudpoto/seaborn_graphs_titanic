# %%
# import library pandas
import pandas as pd

# loading a dataset 
netflix = pd.read_csv("https://raw.githubusercontent.com/practiceprobs/datasets/main/netflix-titles/netflix-titles.csv")
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
netflix.shape
# Out:
# (8807, 12)

# %%
netflix.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
netflix=pd.read_csv("https://raw.githubusercontent.com/practiceprobs/datasets/main/netflix-titles/netflix-titles.csv")

# %%
netflix.tail(10)
# Out:
#      show_id     type               title                 director  \
# 8797   s8798  TV Show           Zak Storm                      NaN
# 8798   s8799    Movie            Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie               Zenda           Avadhoot Gupte
# 8800   s8801  TV Show  Zindagi Gulzar Hai                      NaN
# 8801   s8802    Movie             Zinzana          Majid Al Ansari
# 8802   s8803    Movie              Zodiac            David Fincher
# 8803   s8804  TV Show         Zombie Dumb                      NaN
# 8804   s8805    Movie          Zombieland          Ruben Fleischer
# 8805   s8806    Movie                Zoom             Peter Hewitt
# 8806   s8807    Movie              Zubaan              Mozez Singh
#
#                                                    cast  \
# 8797  Michael Johnston, Jessica Gee-George, Christin...
# 8798  Adil Hussain, Mona Singh, K.K. Raina, Sanjay M...
# 8799  Santosh Juvekar, Siddharth Chandekar, Sachit P...
# ...

# %%
netflix.country['Pakistan'].show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 netflix.country['Pakistan'].show()
#
# File c:\Users\Rozba\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File c:\Users\Rozba\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# ...

# %%
# show rows where country is Pakistan
netflix[netflix.country=='Pakistan']
# Out:
#      show_id     type                        title                 director  \
# 3536   s3537    Movie                       Saawan              Farhan Alam
# 4186   s4187    Movie  Abdullah, The Final Witness       Hashim Nadeem Khan
# 4191   s4192    Movie                         Pari            Syed Atif Ali
# 4328   s4329    Movie             Teefa in Trouble              Ahsan Rahim
# 4615   s4616    Movie     Zindagi Kitni Haseen Hay            Anjum Shahzad
# 6025   s6026    Movie            7 Din Mohabbat In  Meenu Gaur, Farjad Nabi
# 6223   s6224    Movie                    Balu Mahi          Haissam Hussain
# 6441   s6442    Movie            Chalay Thay Saath                Umer Adil
# 6484   s6485    Movie                Chupan Chupai               Mohsin Ali
# 6980   s6981    Movie               Ho Mann Jahaan                Asim Raza
# 7024   s7025  TV Show                     Humsafar                      NaN
# ...

# %%
netflix[netflix.director=='Bilal Lashari']
# Out:
#      show_id   type title       director  \
# 8686   s8687  Movie  Waar  Bilal Lashari
#
#                                                    cast   country  \
# 8686  Shaan Shahid, Shamoon Abbasi, Ayesha Khan, Mee...  Pakistan
#
#         date_added  release_year rating duration  \
# 8686  July 1, 2017          2013  TV-MA  130 min
#
#                                      listed_in  \
# 8686  Action & Adventure, International Movies
#
#                                             description
# 8686  When Pakistani authorities learn of a looming ...

# %%
pd.dropna("description")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [18], line 1
# ----> 1 pd.dropna("description")
#
# File c:\Users\Rozba\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'dropna'

# %%
# drop the column of description
netflix.drop('description',axis=1)
# Out:
#      show_id   type title       director  \
# 8686   s8687  Movie  Waar  Bilal Lashari
#
#                                                    cast   country  \
# 8686  Shaan Shahid, Shamoon Abbasi, Ayesha Khan, Mee...  Pakistan
#
#         date_added  release_year rating duration  \
# 8686  July 1, 2017          2013  TV-MA  130 min
#
#                                      listed_in
# 8686  Action & Adventure, International Movies
